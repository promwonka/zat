# %%
import pandas as pd
import numpy as np
plt.style.use("seaborn")
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df = pd.read_csv('eu19.csv')
df['currency'] = 'eurusd'
df.rename(columns = {'UTC':'utc', 'AskPrice':'askprice','BidPrice':'bidprice','AskVolume':'askvolume','BidVolume':'bidvolume'}, inplace = True)
df.index.names = ['d_id']
#df = df[:680000]
df.to_csv('eu19psql.csv')

# %%
df
# Out:
#                                      utc  askprice  bidprice  askvolume  \
# d_id
# 0       2019-01-01 22:02:37.254000+00:00   1.14598   1.14682    3.75000
# 1       2019-01-01 22:02:38.590000+00:00   1.14599   1.14682    2.25000
# 2       2019-01-01 22:02:39.138000+00:00   1.14599   1.14684    3.75000
# 3       2019-01-01 22:02:55.787000+00:00   1.14598   1.14684    3.75000
# 4       2019-01-01 22:03:02.060000+00:00   1.14598   1.14684    3.75000
# ...                                  ...       ...       ...        ...
# 679995  2019-01-07 16:00:00.123000+00:00   1.14634   1.14636    2.70000
# 679996  2019-01-07 16:00:00.225000+00:00   1.14633   1.14636    1.00000
# 679997  2019-01-07 16:00:00.328000+00:00   1.14634   1.14637    2.25000
# 679998  2019-01-07 16:00:00.437000+00:00   1.14634   1.14636    1.25000
# 679999  2019-01-07 16:00:00.488000+00:00   1.14633   1.14635    1.00000
#
#         bidvolume currency
# d_id
# 0         0.75000   eurusd
# 1         0.75000   eurusd
# ...
